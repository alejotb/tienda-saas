# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Depuración de sintaxis Dart para `checkout_full_page_widget.dart`\n",
    "\n",
    "Este notebook analiza el archivo con errores de sintaxis de Flutter/Dart y ayuda a corregir el widget tree final usando el archivo de contexto `ennegram_context` como guía."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from pathlib import Path\n",
    "\n",
    "path = Path('lib/pages/checkout_full_page/checkout_full_page_widget.dart')\n",
    "text = path.read_text(encoding='utf-8')\n",
    "lines = text.splitlines()\n",
    "for i, line in enumerate(lines[:250], start=1):\n",
    "    if i in (138, 170, 2242, 2243, 2244, 2245, 2246):\n",
    "        print(f'{i}: {line}')\n",
    "\n",
    "# Balance check\n",
    "for open_br, close_br in [('(', ')'), ('[', ']'), ('{', '}')]:\n",
    "    stack = []\n",
    "    for i, ch in enumerate(text, start=1):\n",
    "        if ch == open_br:\n",
    "            stack.append(i)\n",
    "        elif ch == close_br:\n",
    "            if stack:\n",
    "                stack.pop()\n",
    "            else:\n",
    "                print(f'unmatched {close_br} at {i}')\n",
    "                break\n",
    "    else:\n",
    "        if stack:\n",
    "            print(f'unmatched {open_br} at {stack[-1]}')\n",
    "        else:\n",
    "            print(f'balanced {open_br}{close_br}')\n"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
